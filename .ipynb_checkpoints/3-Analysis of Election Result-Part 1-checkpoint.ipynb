# %%
import os
import pandas as pd

# %%
output_folder_electionresult = "election_results"
output_folder_partiesresult = "winners.csv"

parliament_df = pd.read_csv("election_analysis/electoral_district.csv")

# Create an empty list to store the winners
winners = []

# %%
import os
import pandas as pd

output_folder_electionresult = "election_results"
output_folder_partiesresult = "winners.csv"
parliament_df = pd.read_csv("election_analysis/electoral_district.csv")

# Define the list of election prefixes
election_prefixes = ["ge14", "ge15"]

# Create an empty list to store the winners
winners = []

# Iterate through the election prefixes
for prefix in election_prefixes:
    # Iterate through the constituency folders
    for folder in os.listdir(output_folder_electionresult):
        constituency_folder = os.path.join(output_folder_electionresult, folder)
        file_prefix = prefix + "_"

        # Iterate through the CSV files for the current election
        for file in os.listdir(constituency_folder):
            if file.startswith(file_prefix):
                file_path = os.path.join(constituency_folder, file)
                print(file_path) # Check if all seats are included
                
                # Read the CSV file into a DataFrame
                df = pd.read_csv(file_path)

                # Rename the parties accordingly                             
                if prefix == "ge14":
                    df["Party"] = df["Party"].replace("Pan-Malaysian Islamic Party", "PAS")
                    df["Party"] = df["Party"].replace("Homeland Solidarity Party", "STAR")
                    df["Party"] = df["Party"].replace("Sabah Heritage Party", "WARISAN")
                    df["Party"] = df["Party"].replace("DAP", "PH")
                elif prefix == "ge15":
                    df["Party"] = df["Party"].replace("DAP", "PH")
                    df["Party"] = df["Party"].replace("Pan-Malaysian Islamic Party", "PN")
                    df["Party"] = df["Party"].replace("Sabah Heritage Party", "WARISAN")
                
                # Determine the winner based on the party with the highest vote count
                winner = df.loc[df["Vote Count"].idxmax(), "Party"]
                highest_vote = df["Vote Count"].max()
                second_highest_vote = df[df["Vote Count"] != highest_vote]["Vote Count"].max()

                # Calculate the percentage of vote
                total_votes = df["Vote Count"].sum()
                df["Percentage of Vote"] = round((df["Vote Count"] / total_votes * 100), 2)

                # Calculate the majority
                majority = highest_vote - second_highest_vote
                percentage_majority = round((majority / total_votes * 100), 2)

                # Append the winner and other data to the list
                winners.append({
                    "Election": prefix,
                    "Parliament Code": folder,
                    "Federal Constituency": parliament_df.loc[parliament_df["Parliament Code"] == folder, "Federal Constituency"].values[0],
                    "Alliance": winner,
                    "Majority": majority,
                    "Percentage of Vote": df.loc[df["Party"] == winner, "Percentage of Vote"].values[0] if len(df.loc[df["Party"] == winner]) > 0 else None,
                    "Total Voters in Constituency": total_votes,
                    "Margin-of-Votes": percentage_majority
                })

# Create a DataFrame from the winners list
winners_df = pd.DataFrame(winners)

# Reorder the columns
winners_df = winners_df[["Election", "Parliament Code", "Federal Constituency", "Alliance", "Majority", "Percentage of Vote", "Total Voters in Constituency", "Margin-of-Votes"]]

# Save the winners DataFrame as a CSV file
#winners_df.to_csv(output_folder_partiesresult, index=False)
# Out:
# election_results\p001\ge14_p001_result.csv
# election_results\p002\ge14_p002_result.csv
# election_results\p003\ge14_p003_result.csv
# election_results\p004\ge14_p004_result.csv
# election_results\p005\ge14_p005_result.csv
# election_results\p006\ge14_p006_result.csv
# election_results\p007\ge14_p007_result.csv
# election_results\p008\ge14_p008_result.csv
# election_results\p009\ge14_p009_result.csv
# election_results\p010\ge14_p010_result.csv
# election_results\p011\ge14_p011_result.csv
# election_results\p012\ge14_p012_result.csv
# election_results\p013\ge14_p013_result.csv
# election_results\p014\ge14_p014_result.csv
# election_results\p015\ge14_p015_result.csv
# election_results\p016\ge14_p016_result.csv
# election_results\p017\ge14_p017_result.csv
# election_results\p018\ge14_p018_result.csv
# election_results\p019\ge14_p019_result.csv
# election_results\p020\ge14_p020_result.csv
# election_results\p021\ge14_p021_result.csv
# election_results\p022\ge14_p022_result.csv
# election_results\p023\ge14_p023_result.csv
# election_results\p024\ge14_p024_result.csv
# election_results\p025\ge14_p025_result.csv
# election_results\p026\ge14_p026_result.csv
# election_results\p027\ge14_p027_result.csv
# election_results\p028\ge14_p028_result.csv
# election_results\p029\ge14_p029_result.csv
# election_results\p030\ge14_p030_result.csv
# election_results\p031\ge14_p031_result.csv
# election_results\p032\ge14_p032_result.csv
# election_results\p033\ge14_p033_result.csv
# election_results\p034\ge14_p034_result.csv
# election_results\p035\ge14_p035_result.csv
# election_results\p036\ge14_p036_result.csv
# election_results\p037\ge14_p037_result.csv
# election_results\p038\ge14_p038_result.csv
# election_results\p039\ge14_p039_result.csv
# election_results\p040\ge14_p040_result.csv
# election_results\p041\ge14_p041_result.csv
# election_results\p042\ge14_p042_result.csv
# election_results\p043\ge14_p043_result.csv
# election_results\p044\ge14_p044_result.csv
# election_results\p045\ge14_p045_result.csv
# election_results\p046\ge14_p046_result.csv
# election_results\p047\ge14_p047_result.csv
# election_results\p048\ge14_p048_result.csv
# election_results\p049\ge14_p049_result.csv
# election_results\p050\ge14_p050_result.csv
# election_results\p051\ge14_p051_result.csv
# election_results\p052\ge14_p052_result.csv
# election_results\p053\ge14_p053_result.csv
# election_results\p054\ge14_p054_result.csv
# election_results\p055\ge14_p055_result.csv
# election_results\p056\ge14_p056_result.csv
# election_results\p057\ge14_p057_result.csv
# election_results\p058\ge14_p058_result.csv
# election_results\p059\ge14_p059_result.csv
# election_results\p060\ge14_p060_result.csv
# election_results\p061\ge14_p061_result.csv
# election_results\p062\ge14_p062_result.csv
# election_results\p063\ge14_p063_result.csv
# election_results\p064\ge14_p064_result.csv
# election_results\p065\ge14_p065_result.csv
# election_results\p066\ge14_p066_result.csv
# election_results\p067\ge14_p067_result.csv
# election_results\p068\ge14_p068_result.csv
# election_results\p069\ge14_p069_result.csv
# election_results\p070\ge14_p070_result.csv
# election_results\p071\ge14_p071_result.csv
# election_results\p072\ge14_p072_result.csv
# election_results\p073\ge14_p073_result.csv
# election_results\p074\ge14_p074_result.csv
# election_results\p075\ge14_p075_result.csv
# election_results\p076\ge14_p076_result.csv
# election_results\p077\ge14_p077_result.csv
# election_results\p078\ge14_p078_result.csv
# election_results\p079\ge14_p079_result.csv
# election_results\p080\ge14_p080_result.csv
# election_results\p081\ge14_p081_result.csv
# election_results\p082\ge14_p082_result.csv
# election_results\p083\ge14_p083_result.csv
# election_results\p084\ge14_p084_result.csv
# election_results\p085\ge14_p085_result.csv
# election_results\p086\ge14_p086_result.csv
# election_results\p087\ge14_p087_result.csv
# election_results\p088\ge14_p088_result.csv
# election_results\p089\ge14_p089_result.csv
# election_results\p090\ge14_p090_result.csv
# election_results\p091\ge14_p091_result.csv
# election_results\p092\ge14_p092_result.csv
# election_results\p093\ge14_p093_result.csv
# election_results\p094\ge14_p094_result.csv
# election_results\p095\ge14_p095_result.csv
# election_results\p096\ge14_p096_result.csv
# election_results\p097\ge14_p097_result.csv
# election_results\p098\ge14_p098_result.csv
# election_results\p099\ge14_p099_result.csv
# election_results\p100\ge14_p100_result.csv
# election_results\p101\ge14_p101_result.csv
# election_results\p102\ge14_p102_result.csv
# election_results\p103\ge14_p103_result.csv
# election_results\p104\ge14_p104_result.csv
# election_results\p105\ge14_p105_result.csv
# election_results\p106\ge14_p106_result.csv
# election_results\p107\ge14_p107_result.csv
# election_results\p108\ge14_p108_result.csv
# election_results\p109\ge14_p109_result.csv
# election_results\p110\ge14_p110_result.csv
# election_results\p111\ge14_p111_result.csv
# election_results\p112\ge14_p112_result.csv
# election_results\p113\ge14_p113_result.csv
# election_results\p114\ge14_p114_result.csv
# election_results\p115\ge14_p115_result.csv
# election_results\p116\ge14_p116_result.csv
# election_results\p117\ge14_p117_result.csv
# election_results\p118\ge14_p118_result.csv
# election_results\p119\ge14_p119_result.csv
# election_results\p120\ge14_p120_result.csv
# election_results\p121\ge14_p121_result.csv
# election_results\p122\ge14_p122_result.csv
# election_results\p123\ge14_p123_result.csv
# election_results\p124\ge14_p124_result.csv
# election_results\p125\ge14_p125_result.csv
# election_results\p126\ge14_p126_result.csv
# election_results\p127\ge14_p127_result.csv
# election_results\p128\ge14_p128_result.csv
# election_results\p129\ge14_p129_result.csv
# election_results\p130\ge14_p130_result.csv
# election_results\p131\ge14_p131_result.csv
# election_results\p132\ge14_p132_result.csv
# election_results\p133\ge14_p133_result.csv
# election_results\p134\ge14_p134_result.csv
# election_results\p135\ge14_p135_result.csv
# election_results\p136\ge14_p136_result.csv
# election_results\p137\ge14_p137_result.csv
# election_results\p138\ge14_p138_result.csv
# election_results\p139\ge14_p139_result.csv
# election_results\p140\ge14_p140_result.csv
# election_results\p141\ge14_p141_result.csv
# election_results\p142\ge14_p142_result.csv
# election_results\p143\ge14_p143_result.csv
# election_results\p144\ge14_p144_result.csv
# election_results\p145\ge14_p145_result.csv
# election_results\p146\ge14_p146_result.csv
# election_results\p147\ge14_p147_result.csv
# election_results\p148\ge14_p148_result.csv
# election_results\p149\ge14_p149_result.csv
# election_results\p150\ge14_p150_result.csv
# election_results\p151\ge14_p151_result.csv
# election_results\p152\ge14_p152_result.csv
# election_results\p153\ge14_p153_result.csv
# election_results\p154\ge14_p154_result.csv
# election_results\p155\ge14_p155_result.csv
# election_results\p156\ge14_p156_result.csv
# election_results\p157\ge14_p157_result.csv
# election_results\p158\ge14_p158_result.csv
# election_results\p159\ge14_p159_result.csv
# election_results\p160\ge14_p160_result.csv
# election_results\p161\ge14_p161_result.csv
# election_results\p162\ge14_p162_result.csv
# election_results\p163\ge14_p163_result.csv
# election_results\p164\ge14_p164_result.csv
# election_results\p165\ge14_p165_result.csv
# election_results\p166\ge14_p166_result.csv
# election_results\p167\ge14_p167_result.csv
# election_results\p168\ge14_p168_result.csv
# election_results\p169\ge14_p169_result.csv
# election_results\p170\ge14_p170_result.csv
# election_results\p171\ge14_p171_result.csv
# election_results\p172\ge14_p172_result.csv
# election_results\p173\ge14_p173_result.csv
# election_results\p174\ge14_p174_result.csv
# election_results\p175\ge14_p175_result.csv
# election_results\p176\ge14_p176_result.csv
# election_results\p177\ge14_p177_result.csv
# election_results\p178\ge14_p178_result.csv
# election_results\p179\ge14_p179_result.csv
# election_results\p180\ge14_p180_result.csv
# election_results\p181\ge14_p181_result.csv
# election_results\p182\ge14_p182_result.csv
# election_results\p183\ge14_p183_result.csv
# election_results\p184\ge14_p184_result.csv
# election_results\p185\ge14_p185_result.csv
# election_results\p186\ge14_p186_result.csv
# election_results\p187\ge14_p187_result.csv
# election_results\p189\ge14_p189_result.csv
# election_results\p190\ge14_p190_result.csv
# election_results\p191\ge14_p191_result.csv
# election_results\p192\ge14_p192_result.csv
# election_results\p193\ge14_p193_result.csv
# election_results\p194\ge14_p194_result.csv
# election_results\p195\ge14_p195_result.csv
# election_results\p196\ge14_p196_result.csv
# election_results\p197\ge14_p197_result.csv
# election_results\p198\ge14_p198_result.csv
# election_results\p199\ge14_p199_result.csv
# election_results\p200\ge14_p200_result.csv
# election_results\p201\ge14_p201_result.csv
# election_results\p202\ge14_p202_result.csv
# election_results\p203\ge14_p203_result.csv
# election_results\p204\ge14_p204_result.csv
# election_results\p205\ge14_p205_result.csv
# election_results\p206\ge14_p206_result.csv
# election_results\p207\ge14_p207_result.csv
# election_results\p208\ge14_p208_result.csv
# election_results\p209\ge14_p209_result.csv
# election_results\p210\ge14_p210_result.csv
# election_results\p211\ge14_p211_result.csv
# election_results\p212\ge14_p212_result.csv
# election_results\p213\ge14_p213_result.csv
# election_results\p214\ge14_p214_result.csv
# election_results\p215\ge14_p215_result.csv
# election_results\p216\ge14_p216_result.csv
# election_results\p217\ge14_p217_result.csv
# election_results\p218\ge14_p218_result.csv
# election_results\p219\ge14_p219_result.csv
# election_results\p220\ge14_p220_result.csv
# election_results\p221\ge14_p221_result.csv
# election_results\p222\ge14_p222_result.csv
# election_results\p001\ge15_p001_result.csv
# election_results\p002\ge15_p002_result.csv
# election_results\p003\ge15_p003_result.csv
# election_results\p004\ge15_p004_result.csv
# election_results\p005\ge15_p005_result.csv
# election_results\p006\ge15_p006_result.csv
# election_results\p007\ge15_p007_result.csv
# election_results\p008\ge15_p008_result.csv
# election_results\p009\ge15_p009_result.csv
# election_results\p010\ge15_p010_result.csv
# election_results\p011\ge15_p011_result.csv
# election_results\p012\ge15_p012_result.csv
# election_results\p013\ge15_p013_result.csv
# election_results\p014\ge15_p014_result.csv
# election_results\p015\ge15_p015_result.csv
# election_results\p016\ge15_p016_result.csv
# election_results\p017\ge15_p017_result.csv
# election_results\p018\ge15_p018_result.csv
# election_results\p019\ge15_p019_result.csv
# election_results\p020\ge15_p020_result.csv
# election_results\p021\ge15_p021_result.csv
# election_results\p022\ge15_p022_result.csv
# election_results\p023\ge15_p023_result.csv
# election_results\p024\ge15_p024_result.csv
# election_results\p025\ge15_p025_result.csv
# election_results\p026\ge15_p026_result.csv
# election_results\p027\ge15_p027_result.csv
# election_results\p028\ge15_p028_result.csv
# election_results\p029\ge15_p029_result.csv
# election_results\p030\ge15_p030_result.csv
# election_results\p031\ge15_p031_result.csv
# election_results\p032\ge15_p032_result.csv
# election_results\p033\ge15_p033_result.csv
# election_results\p034\ge15_p034_result.csv
# election_results\p035\ge15_p035_result.csv
# election_results\p036\ge15_p036_result.csv
# election_results\p037\ge15_p037_result.csv
# election_results\p038\ge15_p038_result.csv
# election_results\p039\ge15_p039_result.csv
# election_results\p040\ge15_p040_result.csv
# election_results\p041\ge15_p041_result.csv
# election_results\p042\ge15_p042_result.csv
# election_results\p043\ge15_p043_result.csv
# election_results\p044\ge15_p044_result.csv
# election_results\p045\ge15_p045_result.csv
# election_results\p046\ge15_p046_result.csv
# election_results\p047\ge15_p047_result.csv
# election_results\p048\ge15_p048_result.csv
# election_results\p049\ge15_p049_result.csv
# election_results\p050\ge15_p050_result.csv
# election_results\p051\ge15_p051_result.csv
# election_results\p052\ge15_p052_result.csv
# election_results\p053\ge15_p053_result.csv
# election_results\p054\ge15_p054_result.csv
# election_results\p055\ge15_p055_result.csv
# election_results\p056\ge15_p056_result.csv
# election_results\p057\ge15_p057_result.csv
# election_results\p058\ge15_p058_result.csv
# election_results\p059\ge15_p059_result.csv
# election_results\p060\ge15_p060_result.csv
# election_results\p061\ge15_p061_result.csv
# election_results\p062\ge15_p062_result.csv
# election_results\p063\ge15_p063_result.csv
# election_results\p064\ge15_p064_result.csv
# election_results\p065\ge15_p065_result.csv
# election_results\p066\ge15_p066_result.csv
# election_results\p067\ge15_p067_result.csv
# election_results\p068\ge15_p068_result.csv
# election_results\p069\ge15_p069_result.csv
# election_results\p070\ge15_p070_result.csv
# election_results\p071\ge15_p071_result.csv
# election_results\p072\ge15_p072_result.csv
# election_results\p073\ge15_p073_result.csv
# election_results\p074\ge15_p074_result.csv
# election_results\p075\ge15_p075_result.csv
# election_results\p076\ge15_p076_result.csv
# election_results\p077\ge15_p077_result.csv
# election_results\p078\ge15_p078_result.csv
# election_results\p079\ge15_p079_result.csv
# election_results\p080\ge15_p080_result.csv
# election_results\p081\ge15_p081_result.csv
# election_results\p082\ge15_p082_result.csv
# election_results\p083\ge15_p083_result.csv
# election_results\p084\ge15_p084_result.csv
# election_results\p085\ge15_p085_result.csv
# election_results\p086\ge15_p086_result.csv
# election_results\p087\ge15_p087_result.csv
# election_results\p088\ge15_p088_result.csv
# election_results\p089\ge15_p089_result.csv
# election_results\p090\ge15_p090_result.csv
# election_results\p091\ge15_p091_result.csv
# election_results\p092\ge15_p092_result.csv
# election_results\p093\ge15_p093_result.csv
# election_results\p094\ge15_p094_result.csv
# election_results\p095\ge15_p095_result.csv
# election_results\p096\ge15_p096_result.csv
# election_results\p097\ge15_p097_result.csv
# election_results\p098\ge15_p098_result.csv
# election_results\p099\ge15_p099_result.csv
# election_results\p100\ge15_p100_result.csv
# election_results\p101\ge15_p101_result.csv
# election_results\p102\ge15_p102_result.csv
# election_results\p103\ge15_p103_result.csv
# election_results\p104\ge15_p104_result.csv
# election_results\p105\ge15_p105_result.csv
# election_results\p106\ge15_p106_result.csv
# election_results\p107\ge15_p107_result.csv
# election_results\p108\ge15_p108_result.csv
# election_results\p109\ge15_p109_result.csv
# election_results\p110\ge15_p110_result.csv
# election_results\p111\ge15_p111_result.csv
# election_results\p112\ge15_p112_result.csv
# election_results\p113\ge15_p113_result.csv
# election_results\p114\ge15_p114_result.csv
# election_results\p115\ge15_p115_result.csv
# election_results\p116\ge15_p116_result.csv
# election_results\p117\ge15_p117_result.csv
# election_results\p118\ge15_p118_result.csv
# election_results\p119\ge15_p119_result.csv
# election_results\p120\ge15_p120_result.csv
# election_results\p121\ge15_p121_result.csv
# election_results\p122\ge15_p122_result.csv
# election_results\p123\ge15_p123_result.csv
# election_results\p124\ge15_p124_result.csv
# election_results\p125\ge15_p125_result.csv
# election_results\p126\ge15_p126_result.csv
# election_results\p127\ge15_p127_result.csv
# election_results\p128\ge15_p128_result.csv
# election_results\p129\ge15_p129_result.csv
# election_results\p130\ge15_p130_result.csv
# election_results\p131\ge15_p131_result.csv
# election_results\p132\ge15_p132_result.csv
# election_results\p133\ge15_p133_result.csv
# election_results\p134\ge15_p134_result.csv
# election_results\p135\ge15_p135_result.csv
# election_results\p136\ge15_p136_result.csv
# election_results\p137\ge15_p137_result.csv
# election_results\p138\ge15_p138_result.csv
# election_results\p139\ge15_p139_result.csv
# election_results\p140\ge15_p140_result.csv
# election_results\p141\ge15_p141_result.csv
# election_results\p142\ge15_p142_result.csv
# election_results\p143\ge15_p143_result.csv
# election_results\p144\ge15_p144_result.csv
# election_results\p145\ge15_p145_result.csv
# election_results\p146\ge15_p146_result.csv
# election_results\p147\ge15_p147_result.csv
# election_results\p148\ge15_p148_result.csv
# election_results\p149\ge15_p149_result.csv
# election_results\p150\ge15_p150_result.csv
# election_results\p151\ge15_p151_result.csv
# election_results\p152\ge15_p152_result.csv
# election_results\p153\ge15_p153_result.csv
# election_results\p154\ge15_p154_result.csv
# election_results\p155\ge15_p155_result.csv
# election_results\p156\ge15_p156_result.csv
# election_results\p157\ge15_p157_result.csv
# election_results\p158\ge15_p158_result.csv
# election_results\p159\ge15_p159_result.csv
# election_results\p160\ge15_p160_result.csv
# election_results\p161\ge15_p161_result.csv
# election_results\p162\ge15_p162_result.csv
# election_results\p163\ge15_p163_result.csv
# election_results\p164\ge15_p164_result.csv
# election_results\p165\ge15_p165_result.csv
# election_results\p166\ge15_p166_result.csv
# election_results\p167\ge15_p167_result.csv
# election_results\p168\ge15_p168_result.csv
# election_results\p169\ge15_p169_result.csv
# election_results\p170\ge15_p170_result.csv
# election_results\p171\ge15_p171_result.csv
# election_results\p172\ge15_p172_result.csv
# election_results\p173\ge15_p173_result.csv
# election_results\p174\ge15_p174_result.csv
# election_results\p175\ge15_p175_result.csv
# election_results\p176\ge15_p176_result.csv
# election_results\p177\ge15_p177_result.csv
# election_results\p178\ge15_p178_result.csv
# election_results\p179\ge15_p179_result.csv
# election_results\p180\ge15_p180_result.csv
# election_results\p181\ge15_p181_result.csv
# election_results\p182\ge15_p182_result.csv
# election_results\p183\ge15_p183_result.csv
# election_results\p184\ge15_p184_result.csv
# election_results\p185\ge15_p185_result.csv
# election_results\p186\ge15_p186_result.csv
# election_results\p187\ge15_p187_result.csv
# election_results\p188\ge15_p188_result.csv
# election_results\p189\ge15_p189_result.csv
# election_results\p190\ge15_p190_result.csv
# election_results\p191\ge15_p191_result.csv
# election_results\p192\ge15_p192_result.csv
# election_results\p193\ge15_p193_result.csv
# election_results\p194\ge15_p194_result.csv
# election_results\p195\ge15_p195_result.csv
# election_results\p196\ge15_p196_result.csv
# election_results\p197\ge15_p197_result.csv
# election_results\p198\ge15_p198_result.csv
# election_results\p199\ge15_p199_result.csv
# election_results\p200\ge15_p200_result.csv
# election_results\p201\ge15_p201_result.csv
# election_results\p202\ge15_p202_result.csv
# election_results\p203\ge15_p203_result.csv
# election_results\p204\ge15_p204_result.csv
# election_results\p205\ge15_p205_result.csv
# election_results\p206\ge15_p206_result.csv
# election_results\p207\ge15_p207_result.csv
# election_results\p208\ge15_p208_result.csv
# election_results\p209\ge15_p209_result.csv
# election_results\p210\ge15_p210_result.csv
# election_results\p211\ge15_p211_result.csv
# election_results\p212\ge15_p212_result.csv
# election_results\p213\ge15_p213_result.csv
# election_results\p214\ge15_p214_result.csv
# election_results\p215\ge15_p215_result.csv
# election_results\p216\ge15_p216_result.csv
# election_results\p217\ge15_p217_result.csv
# election_results\p218\ge15_p218_result.csv
# election_results\p219\ge15_p219_result.csv
# election_results\p220\ge15_p220_result.csv
# election_results\p221\ge15_p221_result.csv
# election_results\p222\ge15_p222_result.csv

# %%
# Create a new column 'Classification' in the winners_df DataFrame
winners_df["Classification"] = ""

# Iterate through each row in the DataFrame
for index, row in winners_df.iterrows():
    percentage_majority = row["Margin-of-Votes"]

    # Assign the classification based on the percentage majority
    if 0.00 <= percentage_majority <= 5.99:
        winners_df.at[index, "Classification"] = "Marginal"
    elif 6.00 <= percentage_majority <= 9.99:
        winners_df.at[index, "Classification"] = "Fairly Safe"
    elif 10.00 <= percentage_majority <= 18.99:
        winners_df.at[index, "Classification"] = "Safe"
    elif percentage_majority >= 19.00:
        winners_df.at[index, "Classification"] = "Very Safe"

# Print the updated DataFrame
winners_df.tail()
#winners_df.to_csv("election_analysis/parliament_margin.csv", index=False)
# Out:
#     Election Parliament Code Federal Constituency Alliance  Majority  \
# 438     ge15            p218               Sibuti      GPS     11745
# 439     ge15            p219                 Miri       PH      6159
# 440     ge15            p220                Baram      GPS      7339
# 441     ge15            p221              Limbang      GPS      9998
# 442     ge15            p222                Lawas      GPS      5677
#
#      Percentage of Vote  Total Voters in Constituency  Margin-of-Votes  \
# 438               65.31                         33916            34.63
# 439               50.61                         78148             7.88
# 440               61.78                         29783            24.64
# 441               75.25                         19796            50.51
# 442               62.40                         18208            31.18
#
#     Classification
# 438      Very Safe
# 439    Fairly Safe
# 440      Very Safe
# 441      Very Safe
# 442      Very Safe

# %%
import os

# Create a directory to store the output files
output_folder = "parties_results"
os.makedirs(output_folder, exist_ok=True)

# Iterate through unique elections in the winners dataframe
for election in winners_df["Election"].unique():
    # Filter the winners for the current election
    election_winners = winners_df[winners_df["Election"] == election]
    
    # Define the output file path
    output_path = os.path.join(output_folder, f"{election}_partiesresults.csv")
    
    # Save the election winners to CSV
    election_winners.to_csv(output_path, index=False)

# %%
# Create a directory to store the output files
output_folder = "parties_results"
os.makedirs(output_folder, exist_ok=True)

# Define the alliances and minor parties for each election
elections = [
    {
        "name": "ge14",
        "alliances": ["PAS", "PH", "BN"],
        "minor_parties": ["Independent", "WARISAN", "STAR"]
    },
    {
        "name": "ge15",
        "alliances": ["PN", "PH", "BN", "GPS", "GRS"],
        "minor_parties": ["Independent", "WARISAN", "MUDA", "PBM", "KDM"]
    }
]

# Iterate through the elections
for election in elections:
    election_name = election["name"]
    alliances = election["alliances"]
    minor_parties = election["minor_parties"]

    # Filter the winners DataFrame for the current election
    election_df = winners_df[winners_df["Election"] == election_name]

    # Iterate through the alliances
    for alliance in alliances:
        # Filter the DataFrame for the current alliance
        alliance_df = election_df[election_df["Alliance"].str.contains(alliance)].copy()

        # Remove duplicate rows
        alliance_df = alliance_df.drop_duplicates()

        # Select the desired columns
        alliance_df = alliance_df[["Federal Constituency", "Parliament Code", "Margin-of-Votes", "Classification"]]

        # Sort the DataFrame by increasing percentage of majority
        alliance_df = alliance_df.sort_values(by="Margin-of-Votes")

        # Save the DataFrame to a CSV file
        alliance_df.to_csv(f"{output_folder}/{election_name}_{alliance.lower()}_seat.csv", index=False)

    # Process the minor parties individually
    minor_df = pd.DataFrame(columns=["Party", "Federal Constituency", "Parliament Code", "Margin-of-Votes", "Classification"])

    for party in minor_parties:
        # Filter the DataFrame for the current party
        party_df = election_df[election_df["Alliance"] == party].copy()

        # Remove duplicate rows
        party_df = party_df.drop_duplicates()

        # Select the desired columns
        party_df = party_df[["Federal Constituency", "Parliament Code", "Margin-of-Votes", "Classification"]]

        # Add the "Party" column
        party_df["Party"] = party

        # Sort the DataFrame by increasing percentage of majority
        party_df = party_df.sort_values(by="Margin-of-Votes")

        # Append the party DataFrame to the minor DataFrame
        minor_df = minor_df.append(party_df, ignore_index=False)

    # Save the minor DataFrame to a CSV file
    minor_df.to_csv(f"{output_folder}/{election_name}_minor_seat.csv", index=False)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11656\1583100448.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   minor_df = minor_df.append(party_df, ignore_index=False)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11656\1583100448.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   minor_df = minor_df.append(party_df, ignore_index=False)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11656\1583100448.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   minor_df = minor_df.append(party_df, ignore_index=False)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11656\1583100448.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   minor_df = minor_df.append(party_df, ignore_index=False)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11656\1583100448.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   minor_df = minor_df.append(party_df, ignore_index=False)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11656\1583100448.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   minor_df = minor_df.append(party_df, ignore_index=False)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11656\1583100448.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   minor_df = minor_df.append(party_df, ignore_index=False)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11656\1583100448.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   minor_df = minor_df.append(party_df, ignore_index=False)

# %%
from bs4 import BeautifulSoup # This module helps in web scrapping.
import requests  # This module helps us to download a web page

import pandas as pd # This module help the dataframe handling
import os # Interacting with system

import time # Calculate duration of code execution

# %%
# This will read the csv file that contains the list of all parliament seats
constituency_file = "election_analysis/electoral_district.csv"
constituency_data = pd.read_csv(constituency_file)

# Creating a folder for the results
output_folder_electionresult = "election_results"

# %%
# Get the start time
start_time = time.time()

print("Scrapping in Progress...")

# This will iterate the code to each parliament seat
for index, row in constituency_data.iterrows():
    constituency_url = row["URL"]
    constituency_code = row["Parliament Code"]
    constituency_name = row["Federal Constituency"]

    # Create output folders for each constituency
    constituency_folder_electionresult = os.path.join(output_folder_electionresult, constituency_code)
    os.makedirs(constituency_folder_electionresult, exist_ok=True)

    # Fetch data from the constituency URL
    data = requests.get(constituency_url)
    soup = BeautifulSoup(data.content, 'html.parser')

    # Use Beautiful Soup to scrape for "table"
    tables = soup.find_all("table")
    
    # This will create a new empty dictionary of election_table and empty list of table_index
    election_table = {}
    table_index = []
    year = 15 # Latest general election

    # Find the desired tables based on specific criteria in html
    for index, table in enumerate(tables):
        caption = table.find("caption")
        if caption and "Malaysian general election" in caption.text:
            rows = table.find_all("tr")
            # Process the selected table
            row_list = []

            for tr in rows:
                td = tr.find_all('td')
                row = [i.text.strip().replace(',', '') for i in td]

                if 'Total valid votes' in row:
                    break

                row_list.append(row[1:5])

            election_table[year] = pd.DataFrame(row_list[1:5], columns=["Party", "Candidate", "Vote Count", "Percentage of Vote"])
            election_table[year].insert(0, 'General Election', year)

            table_index.append(year)
            year -= 1
            
            if year == 13:
                break

    # Print and save the dataframes for the constituency
    print(f"{constituency_code.upper().zfill(3)}",constituency_name)
    for year in table_index:
        # Define the path for the CSV file in the output folder
        csv_path = os.path.join(constituency_folder_electionresult, f"ge{year}_{constituency_code}_result.csv")

        # Save the election table for the current year as a CSV file
        election_table[year].to_csv(csv_path, index=False)
        print(f"{constituency_code.upper().zfill(3)}-GE{year} csv data completed")
    print()
        
print("Scrapping completed!")

# Get the end time
end_time = time.time()

# Calculate the duration in seconds
duration = end_time - start_time

# Convert duration to a more readable format
minutes = duration // 60
seconds = duration % 60

# Print the duration
print(f"Code execution time: {minutes:.0f} minutes {seconds:.2f} seconds")
# Out:
# Scrapping in Progress...
# P001 Padang Besar
# P001-GE15 csv data completed
# P001-GE14 csv data completed
#
# P002 Kangar
# P002-GE15 csv data completed
# P002-GE14 csv data completed
#
# P003 Arau
# P003-GE15 csv data completed
# P003-GE14 csv data completed
#
# P004 Langkawi
# P004-GE15 csv data completed
# P004-GE14 csv data completed
#
# P005 Jerlun
# P005-GE15 csv data completed
# P005-GE14 csv data completed
#
# P006 Kubang Pasu
# P006-GE15 csv data completed
# P006-GE14 csv data completed
#
# P007 Padang Terap
# P007-GE15 csv data completed
# P007-GE14 csv data completed
#
# P008 Pokok Sena
# P008-GE15 csv data completed
# P008-GE14 csv data completed
#
# P009 Alor Setar
# P009-GE15 csv data completed
# P009-GE14 csv data completed
#
# P010 Kuala Kedah
# P010-GE15 csv data completed
# P010-GE14 csv data completed
#
# P011 Pendang
# P011-GE15 csv data completed
# P011-GE14 csv data completed
#
# P012 Jerai
# P012-GE15 csv data completed
# P012-GE14 csv data completed
#
# P013 Sik
# P013-GE15 csv data completed
# P013-GE14 csv data completed
#
# P014 Merbok
# P014-GE15 csv data completed
# P014-GE14 csv data completed
#
# P015 Sungai Petani
# P015-GE15 csv data completed
# P015-GE14 csv data completed
#
# P016 Baling
# P016-GE15 csv data completed
# P016-GE14 csv data completed
#
# P017 Padang Serai
# P017-GE15 csv data completed
# P017-GE14 csv data completed
#
# P018 Kulim-Bandar Baharu
# P018-GE15 csv data completed
# P018-GE14 csv data completed
#
# P019 Tumpat
# P019-GE15 csv data completed
# P019-GE14 csv data completed
#
# P020 Pengkalan Chepa
# P020-GE15 csv data completed
# P020-GE14 csv data completed
#
# P021 Kota Bharu
# P021-GE15 csv data completed
# P021-GE14 csv data completed
#
# P022 Pasir Mas
# P022-GE15 csv data completed
# P022-GE14 csv data completed
#
# P023 Rantau Panjang
# P023-GE15 csv data completed
# P023-GE14 csv data completed
#
# P024 Kubang Kerian
# P024-GE15 csv data completed
# P024-GE14 csv data completed
#
# P025 Bachok
# P025-GE15 csv data completed
# P025-GE14 csv data completed
#
# P026 Ketereh
# P026-GE15 csv data completed
# P026-GE14 csv data completed
#
# P027 Tanah Merah
# P027-GE15 csv data completed
# P027-GE14 csv data completed
#
# P028 Pasir Puteh
# P028-GE15 csv data completed
# P028-GE14 csv data completed
#
# P029 Machang
# P029-GE15 csv data completed
# P029-GE14 csv data completed
#
# P030 Jeli
# P030-GE15 csv data completed
# P030-GE14 csv data completed
#
# P031 Kuala Krai
# P031-GE15 csv data completed
# P031-GE14 csv data completed
#
# P032 Gua Musang
# P032-GE15 csv data completed
# P032-GE14 csv data completed
#
# P033 Besut
# P033-GE15 csv data completed
# P033-GE14 csv data completed
#
# P034 Setiu
# P034-GE15 csv data completed
# P034-GE14 csv data completed
#
# P035 Kuala Nerus
# P035-GE15 csv data completed
# P035-GE14 csv data completed
#
# P036 Kuala Terengganu
# P036-GE15 csv data completed
# P036-GE14 csv data completed
#
# P037 Marang
# P037-GE15 csv data completed
# P037-GE14 csv data completed
#
# P038 Hulu Terengganu
# P038-GE15 csv data completed
# P038-GE14 csv data completed
#
# P039 Dungun
# P039-GE15 csv data completed
# P039-GE14 csv data completed
#
# P040 Kemaman
# P040-GE15 csv data completed
# P040-GE14 csv data completed
#
# P041 Kepala Batas
# P041-GE15 csv data completed
# P041-GE14 csv data completed
#
# P042 Tasek Gelugor
# P042-GE15 csv data completed
# P042-GE14 csv data completed
#
# P043 Bagan
# P043-GE15 csv data completed
# P043-GE14 csv data completed
#
# P044 Permatang Pauh
# P044-GE15 csv data completed
# P044-GE14 csv data completed
#
# P045 Bukit Mertajam
# P045-GE15 csv data completed
# P045-GE14 csv data completed
#
# P046 Batu Kawan
# P046-GE15 csv data completed
# P046-GE14 csv data completed
#
# P047 Nibong Tebal
# P047-GE15 csv data completed
# P047-GE14 csv data completed
#
# P048 Bukit Bendera
# P048-GE15 csv data completed
# P048-GE14 csv data completed
#
# P049 Tanjong
# P049-GE15 csv data completed
# P049-GE14 csv data completed
#
# P050 Jelutong
# P050-GE15 csv data completed
# P050-GE14 csv data completed
#
# P051 Bukit Gelugor
# P051-GE15 csv data completed
# P051-GE14 csv data completed
#
# P052 Bayan Baru
# P052-GE15 csv data completed
# P052-GE14 csv data completed
#
# P053 Balik Pulau
# P053-GE15 csv data completed
# P053-GE14 csv data completed
#
# P054 Gerik
# P054-GE15 csv data completed
# P054-GE14 csv data completed
#
# P055 Lenggong
# P055-GE15 csv data completed
# P055-GE14 csv data completed
#
# P056 Larut
# P056-GE15 csv data completed
# P056-GE14 csv data completed
#
# P057 Parit Buntar
# P057-GE15 csv data completed
# P057-GE14 csv data completed
#
# P058 Bagan Serai
# P058-GE15 csv data completed
# P058-GE14 csv data completed
#
# P059 Bukit Gantang
# P059-GE15 csv data completed
# P059-GE14 csv data completed
#
# P060 Taiping
# P060-GE15 csv data completed
# P060-GE14 csv data completed
#
# P061 Padang Rengas
# P061-GE15 csv data completed
# P061-GE14 csv data completed
#
# P062 Sungai Siput
# P062-GE15 csv data completed
# P062-GE14 csv data completed
#
# P063 Tambun
# P063-GE15 csv data completed
# P063-GE14 csv data completed
#
# P064 Ipoh Timor
# P064-GE15 csv data completed
# P064-GE14 csv data completed
#
# P065 Ipoh Barat
# P065-GE15 csv data completed
# P065-GE14 csv data completed
#
# P066 Batu Gajah
# P066-GE15 csv data completed
# P066-GE14 csv data completed
#
# P067 Kuala Kangsar
# P067-GE15 csv data completed
# P067-GE14 csv data completed
#
# P068 Beruas
# P068-GE15 csv data completed
# P068-GE14 csv data completed
#
# P069 Parit
# P069-GE15 csv data completed
# P069-GE14 csv data completed
#
# P070 Kampar
# P070-GE15 csv data completed
# P070-GE14 csv data completed
#
# P071 Gopeng
# P071-GE15 csv data completed
# P071-GE14 csv data completed
#
# P072 Tapah
# P072-GE15 csv data completed
# P072-GE14 csv data completed
#
# P073 Pasir Salak
# P073-GE15 csv data completed
# P073-GE14 csv data completed
#
# P074 Lumut
# P074-GE15 csv data completed
# P074-GE14 csv data completed
#
# P075 Bagan Datuk
# P075-GE15 csv data completed
# P075-GE14 csv data completed
#
# P076 Teluk Intan
# P076-GE15 csv data completed
# P076-GE14 csv data completed
#
# P077 Tanjong Malim
# P077-GE15 csv data completed
# P077-GE14 csv data completed
#
# P078 Cameron Highlands
# P078-GE15 csv data completed
# P078-GE14 csv data completed
#
# P079 Lipis
# P079-GE15 csv data completed
# P079-GE14 csv data completed
#
# P080 Raub
# P080-GE15 csv data completed
# P080-GE14 csv data completed
#
# P081 Jerantut
# P081-GE15 csv data completed
# P081-GE14 csv data completed
#
# P082 Indera Mahkota
# P082-GE15 csv data completed
# P082-GE14 csv data completed
#
# P083 Kuantan
# P083-GE15 csv data completed
# P083-GE14 csv data completed
#
# P084 Paya Besar
# P084-GE15 csv data completed
# P084-GE14 csv data completed
#
# P085 Pekan
# P085-GE15 csv data completed
# P085-GE14 csv data completed
#
# P086 Maran
# P086-GE15 csv data completed
# P086-GE14 csv data completed
#
# P087 Kuala Krau
# P087-GE15 csv data completed
# P087-GE14 csv data completed
#
# P088 Temerloh
# P088-GE15 csv data completed
# P088-GE14 csv data completed
#
# P089 Bentong
# P089-GE15 csv data completed
# P089-GE14 csv data completed
#
# P090 Bera
# P090-GE15 csv data completed
# P090-GE14 csv data completed
#
# P091 Rompin
# P091-GE15 csv data completed
# P091-GE14 csv data completed
#
# P092 Sabak Bernam
# P092-GE15 csv data completed
# P092-GE14 csv data completed
#
# P093 Sungai Besar
# P093-GE15 csv data completed
# P093-GE14 csv data completed
#
# P094 Hulu Selangor
# P094-GE15 csv data completed
# P094-GE14 csv data completed
#
# P095 Tanjong Karang
# P095-GE15 csv data completed
# P095-GE14 csv data completed
#
# P096 Kuala Selangor
# P096-GE15 csv data completed
# P096-GE14 csv data completed
#
# P097 Selayang
# P097-GE15 csv data completed
# P097-GE14 csv data completed
#
# P098 Gombak
# P098-GE15 csv data completed
# P098-GE14 csv data completed
#
# P099 Ampang
# P099-GE15 csv data completed
# P099-GE14 csv data completed
#
# P100 Pandan
# P100-GE15 csv data completed
# P100-GE14 csv data completed
#
# P101 Hulu Langat
# P101-GE15 csv data completed
# P101-GE14 csv data completed
#
# P102 Bangi
# P102-GE15 csv data completed
# P102-GE14 csv data completed
#
# P103 Puchong
# P103-GE15 csv data completed
# P103-GE14 csv data completed
#
# P104 Subang
# P104-GE15 csv data completed
# P104-GE14 csv data completed
#
# P105 Petaling Jaya
# P105-GE15 csv data completed
# P105-GE14 csv data completed
#
# P106 Damansara
# P106-GE15 csv data completed
# P106-GE14 csv data completed
#
# P107 Sungai Buloh
# P107-GE15 csv data completed
# P107-GE14 csv data completed
#
# P108 Shah Alam
# P108-GE15 csv data completed
# P108-GE14 csv data completed
#
# P109 Kapar
# P109-GE15 csv data completed
# P109-GE14 csv data completed
#
# P110 Klang
# P110-GE15 csv data completed
# P110-GE14 csv data completed
#
# P111 Kota Raja
# P111-GE15 csv data completed
# P111-GE14 csv data completed
#
# P112 Kuala Langat
# P112-GE15 csv data completed
# P112-GE14 csv data completed
#
# P113 Sepang
# P113-GE15 csv data completed
# P113-GE14 csv data completed
#
# P114 Kepong
# P114-GE15 csv data completed
# P114-GE14 csv data completed
#
# P115 Batu
# P115-GE15 csv data completed
# P115-GE14 csv data completed
#
# P116 Wangsa Maju
# P116-GE15 csv data completed
# P116-GE14 csv data completed
#
# P117 Segambut
# P117-GE15 csv data completed
# P117-GE14 csv data completed
#
# P118 Setiawangsa
# P118-GE15 csv data completed
# P118-GE14 csv data completed
#
# P119 Titiwangsa
# P119-GE15 csv data completed
# P119-GE14 csv data completed
#
# P120 Bukit Bintang
# P120-GE15 csv data completed
# P120-GE14 csv data completed
#
# P121 Lembah Pantai
# P121-GE15 csv data completed
# P121-GE14 csv data completed
#
# P122 Seputeh
# P122-GE15 csv data completed
# P122-GE14 csv data completed
#
# P123 Cheras
# P123-GE15 csv data completed
# P123-GE14 csv data completed
#
# P124 Bandar Tun Razak
# P124-GE15 csv data completed
# P124-GE14 csv data completed
#
# P125 Putrajaya
# P125-GE15 csv data completed
# P125-GE14 csv data completed
#
# P126 Jelebu
# P126-GE15 csv data completed
# P126-GE14 csv data completed
#
# P127 Jempol
# P127-GE15 csv data completed
# P127-GE14 csv data completed
#
# P128 Seremban
# P128-GE15 csv data completed
# P128-GE14 csv data completed
#
# P129 Kuala Pilah
# P129-GE15 csv data completed
# P129-GE14 csv data completed
#
# P130 Rasah
# P130-GE15 csv data completed
# P130-GE14 csv data completed
#
# P131 Rembau
# P131-GE15 csv data completed
# P131-GE14 csv data completed
#
# P132 Port Dickson
# P132-GE15 csv data completed
# P132-GE14 csv data completed
#
# P133 Tampin
# P133-GE15 csv data completed
# P133-GE14 csv data completed
#
# P134 Masjid Tanah
# P134-GE15 csv data completed
# P134-GE14 csv data completed
#
# P135 Alor Gajah
# P135-GE15 csv data completed
# P135-GE14 csv data completed
#
# P136 Tangga Batu
# P136-GE15 csv data completed
# P136-GE14 csv data completed
#
# P137 Hang Tuah Jaya
# P137-GE15 csv data completed
# P137-GE14 csv data completed
#
# P138 Kota Melaka
# P138-GE15 csv data completed
# P138-GE14 csv data completed
#
# P139 Jasin
# P139-GE15 csv data completed
# P139-GE14 csv data completed
#
# P140 Segamat
# P140-GE15 csv data completed
# P140-GE14 csv data completed
#
# P141 Sekijang
# P141-GE15 csv data completed
# P141-GE14 csv data completed
#
# P142 Labis
# P142-GE15 csv data completed
# P142-GE14 csv data completed
#
# P143 Pagoh
# P143-GE15 csv data completed
# P143-GE14 csv data completed
#
# P144 Ledang
# P144-GE15 csv data completed
# P144-GE14 csv data completed
#
# P145 Bakri
# P145-GE15 csv data completed
# P145-GE14 csv data completed
#
# P146 Muar
# P146-GE15 csv data completed
# P146-GE14 csv data completed
#
# P147 Parit Sulong
# P147-GE15 csv data completed
# P147-GE14 csv data completed
#
# P148 Ayer Hitam
# P148-GE15 csv data completed
# P148-GE14 csv data completed
#
# P149 Sri Gading
# P149-GE15 csv data completed
# P149-GE14 csv data completed
#
# P150 Batu Pahat
# P150-GE15 csv data completed
# P150-GE14 csv data completed
#
# P151 Simpang Renggam
# P151-GE15 csv data completed
# P151-GE14 csv data completed
#
# P152 Kluang
# P152-GE15 csv data completed
# P152-GE14 csv data completed
#
# P153 Sembrong
# P153-GE15 csv data completed
# P153-GE14 csv data completed
#
# P154 Mersing
# P154-GE15 csv data completed
# P154-GE14 csv data completed
#
# P155 Tenggara
# P155-GE15 csv data completed
# P155-GE14 csv data completed
#
# P156 Kota Tinggi
# P156-GE15 csv data completed
# P156-GE14 csv data completed
#
# P157 Pengerang
# P157-GE15 csv data completed
# P157-GE14 csv data completed
#
# P158 Tebrau
# P158-GE15 csv data completed
# P158-GE14 csv data completed
#
# P159 Pasir Gudang
# P159-GE15 csv data completed
# P159-GE14 csv data completed
#
# P160 Johor Bahru
# P160-GE15 csv data completed
# P160-GE14 csv data completed
#
# P161 Pulai
# P161-GE15 csv data completed
# P161-GE14 csv data completed
#
# P162 Iskandar Puteri
# P162-GE15 csv data completed
# P162-GE14 csv data completed
#
# P163 Kulai
# P163-GE15 csv data completed
# P163-GE14 csv data completed
#
# P164 Pontian
# P164-GE15 csv data completed
# P164-GE14 csv data completed
#
# P165 Tanjung Piai
# P165-GE15 csv data completed
# P165-GE14 csv data completed
#
# P166 Labuan
# P166-GE15 csv data completed
# P166-GE14 csv data completed
#
# P167 Kudat
# P167-GE15 csv data completed
# P167-GE14 csv data completed
#
# P168 Kota Marudu
# P168-GE15 csv data completed
# P168-GE14 csv data completed
#
# P169 Kota Belud
# P169-GE15 csv data completed
# P169-GE14 csv data completed
#
# P170 Tuaran
# P170-GE15 csv data completed
# P170-GE14 csv data completed
#
# P171 Sepanggar
# P171-GE15 csv data completed
# P171-GE14 csv data completed
#
# P172 Kota Kinabalu
# P172-GE15 csv data completed
# P172-GE14 csv data completed
#
# P173 Putatan
# P173-GE15 csv data completed
# P173-GE14 csv data completed
#
# P174 Penampang
# P174-GE15 csv data completed
# P174-GE14 csv data completed
#
# P175 Papar
# P175-GE15 csv data completed
# P175-GE14 csv data completed
#
# P176 Kimanis
# P176-GE15 csv data completed
# P176-GE14 csv data completed
#
# P177 Beaufort
# P177-GE15 csv data completed
# P177-GE14 csv data completed
#
# P178 Sipitang
# P178-GE15 csv data completed
# P178-GE14 csv data completed
#
# P179 Ranau
# P179-GE15 csv data completed
# P179-GE14 csv data completed
#
# P180 Keningau
# P180-GE15 csv data completed
# P180-GE14 csv data completed
#
# P181 Tenom
# P181-GE15 csv data completed
# P181-GE14 csv data completed
#
# P182 Pensiangan
# P182-GE15 csv data completed
# P182-GE14 csv data completed
#
# P183 Beluran
# P183-GE15 csv data completed
# P183-GE14 csv data completed
#
# P184 Libaran
# P184-GE15 csv data completed
# P184-GE14 csv data completed
#
# P185 Batu Sapi
# P185-GE15 csv data completed
# P185-GE14 csv data completed
#
# P186 Sandakan
# P186-GE15 csv data completed
# P186-GE14 csv data completed
#
# P187 Kinabatangan
# P187-GE15 csv data completed
# P187-GE14 csv data completed
#
# P188 Lahad Datu
# P188-GE15 csv data completed
#
# P189 Semporna
# P189-GE15 csv data completed
# P189-GE14 csv data completed
#
# P190 Tawau
# P190-GE15 csv data completed
# P190-GE14 csv data completed
#
# P191 Kalabakan
# P191-GE15 csv data completed
# P191-GE14 csv data completed
#
# P192 Mas Gading
# P192-GE15 csv data completed
# P192-GE14 csv data completed
#
# P193 Santubong
# P193-GE15 csv data completed
# P193-GE14 csv data completed
#
# P194 Petra Jaya
# P194-GE15 csv data completed
# P194-GE14 csv data completed
#
# P195 Bandar Kuching
# P195-GE15 csv data completed
# P195-GE14 csv data completed
#
# P196 Stampin
# P196-GE15 csv data completed
# P196-GE14 csv data completed
#
# P197 Kota Samarahan
# P197-GE15 csv data completed
# P197-GE14 csv data completed
#
# P198 Puncak Borneo
# P198-GE15 csv data completed
# P198-GE14 csv data completed
#
# P199 Serian
# P199-GE15 csv data completed
# P199-GE14 csv data completed
#
# P200 Batang Sadong
# P200-GE15 csv data completed
# P200-GE14 csv data completed
#
# P201 Batang Lupar
# P201-GE15 csv data completed
# P201-GE14 csv data completed
#
# P202 Sri Aman
# P202-GE15 csv data completed
# P202-GE14 csv data completed
#
# P203 Lubok Antu
# P203-GE15 csv data completed
# P203-GE14 csv data completed
#
# P204 Betong
# P204-GE15 csv data completed
# P204-GE14 csv data completed
#
# P205 Saratok
# P205-GE15 csv data completed
# P205-GE14 csv data completed
#
# P206 Tanjong Manis
# P206-GE15 csv data completed
# P206-GE14 csv data completed
#
# P207 Igan
# P207-GE15 csv data completed
# P207-GE14 csv data completed
#
# P208 Sarikei
# P208-GE15 csv data completed
# P208-GE14 csv data completed
#
# P209 Julau
# P209-GE15 csv data completed
# P209-GE14 csv data completed
#
# P210 Kanowit
# P210-GE15 csv data completed
# P210-GE14 csv data completed
#
# P211 Lanang
# P211-GE15 csv data completed
# P211-GE14 csv data completed
#
# P212 Sibu
# P212-GE15 csv data completed
# P212-GE14 csv data completed
#
# P213 Mukah
# P213-GE15 csv data completed
# P213-GE14 csv data completed
#
# P214 Selangau
# P214-GE15 csv data completed
# P214-GE14 csv data completed
#
# P215 Kapit
# P215-GE15 csv data completed
# P215-GE14 csv data completed
#
# P216 Hulu Rajang
# P216-GE15 csv data completed
# P216-GE14 csv data completed
#
# P217 Bintulu
# P217-GE15 csv data completed
# P217-GE14 csv data completed
#
# P218 Sibuti
# P218-GE15 csv data completed
# P218-GE14 csv data completed
#
# P219 Miri
# P219-GE15 csv data completed
# P219-GE14 csv data completed
#
# P220 Baram
# P220-GE15 csv data completed
# P220-GE14 csv data completed
#
# P221 Limbang
# P221-GE15 csv data completed
# P221-GE14 csv data completed
#
# P222 Lawas
# P222-GE15 csv data completed
# P222-GE14 csv data completed
#
# Scrapping completed!
# Code execution time: 3 minutes 5.50 seconds
